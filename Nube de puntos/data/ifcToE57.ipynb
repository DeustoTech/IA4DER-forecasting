# %% [markdown]
# Convertir el render de la subestación (archivo ifc) a una nube de puntos xyz que luego se puede abrir y exportar en cloud compare como un e57

# %%
import ifcopenshell
import ifcopenshell.geom
import open3d as o3d
import numpy as np

# Abrir el archivo IFC
ifc_file = ifcopenshell.open('Modelo_IFC.ifc')

# Crear un contexto de geometría
settings = ifcopenshell.geom.settings()
settings.set(settings.USE_WORLD_COORDS, True)

all_points = []  # Lista para almacenar todos los puntos

# Iterar sobre todos los productos con representación geométrica
for product in ifc_file.by_type("IfcProduct"):
    if product.Representation:
        try:
            # Crear la geometría del producto
            shape = ifcopenshell.geom.create_shape(settings, product)
            vertices = shape.geometry.verts  # Acceder a los vértices

            # Los vértices vienen como una lista lineal (x1, y1, z1, x2, y2, z2,...)
            # Convertir a una matriz Nx3 (coordenadas XYZ)
            points = np.array(vertices).reshape((-1, 3))
            all_points.append(points)  # Agregar los puntos a la lista

        except Exception as e:
            print(f"Error procesando la geometría del producto {product}: {e}")
    else:
        print(f"El producto {product} no tiene representación.")

# Unir todos los puntos en una sola matriz Nx3
if all_points:
    all_points = np.vstack(all_points)
else:
    print("No se encontraron puntos para la nube de puntos.")

# Crear la nube de puntos en Open3D
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(all_points)

# Visualizar la nube de puntos
o3d.visualization.draw_geometries([pcd])
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# El producto #25901=IfcCurtainWall('2JX6RZsXv7NvAwKJnYfLb9',#18,'Muro cortina:Muro cortina - CASETA:1002100',$,'Muro cortina:Muro cortina - CASETA',#25900,$,'1002100') no tiene representación.
# El producto #28503=IfcCurtainWall('2JX6RZsXv7NvAwKJnYfLX7',#18,'Muro cortina:Muro cortina - CASETA:1002362',$,'Muro cortina:Muro cortina - CASETA',#28502,$,'1002362') no tiene representación.
# El producto #31211=IfcCurtainWall('2xIreFXzzES8Q0CITO6i$o',#18,'Muro cortina:Muro cortina - CASETA:1002967',$,'Muro cortina:Muro cortina - CASETA',#31210,$,'1002967') no tiene representación.
# El producto #36492=IfcCurtainWall('0JjxQSyhzBlfut4wVze5DO',#18,'Muro cortina:Muro cortina - CASETA:1015405',$,'Muro cortina:Muro cortina - CASETA',#36491,$,'1015405') no tiene representación.
# El producto #40817=IfcCurtainWall('33IcWl2Tb7SPMS8ajI2HWS',#18,'Muro cortina:Muro cortina - ACCESO_:1022267',$,'Muro cortina:Muro cortina - ACCESO_',#40816,$,'1022267') no tiene representación.
# El producto #48334=IfcCurtainWall('1mK2Vm5iP5pghJd26VFNPD',#18,'Muro cortina:Muro cortina - ACCESO_:1090114',$,'Muro cortina:Muro cortina - ACCESO_',#48333,$,'1090114') no tiene representación.
# El producto #49374=IfcCurtainWall('1aqc3Nxc9DSB6b29KGNbEL',#18,'Muro cortina:Muro cortina - ACCESO_:1121066',$,'Muro cortina:Muro cortina - ACCESO_',#49373,$,'1121066') no tiene representación.
# El producto #21324=IfcRoof('3JYUZ4O3L2YuosIs4CqdvP',#18,'Cubierta básica:Cubierta - por defecto - 20 cm:866801',$,'Cubierta básica:Cubierta - por defecto - 20 cm',#21322,$,'866801',.NOTDEFINED.) no tiene representación.
# El producto #23127=IfcStair('2kIOUPrxr6e9RjVGlqMN2N',#18,'Escalera moldeada in situ:Escalera:989172',$,'Escalera moldeada in situ:Losa de hormigón - C=17cm H=30cm 2',#23126,$,'989172',.STRAIGHT_RUN_STAIR.) no tiene representación.
# El producto #23288=IfcStair('1zCZcSEu911Qd0e1fM8y4m',#18,'Escalera moldeada in situ:Escalera:990748',$,'Escalera moldeada in situ:Losa de hormigón - C=17cm H=30cm 2',#23287,$,'990748',.STRAIGHT_RUN_STAIR.) no tiene representación.
# El producto #36263=IfcStair('05bwEYohPAZAv6x0JSWeID',#18,'Escalera moldeada in situ:Escalera:1008639',$,'Escalera moldeada in situ:Losa de hormigón - C=17cm H=30cm 2',#36262,$,'1008639',.STRAIGHT_RUN_STAIR.) no tiene representación.
# El producto #120732=IfcStair('39PgYrWtPCxxlCN9zhlKh6',#18,'Escaleras Trafo 1:Escaleras Trafo 1:1433290',$,'Escaleras Trafo 1:Escaleras Trafo 1',#120727,$,'1433290',.NOTDEFINED.) no tiene representación.
# Error procesando la geometría del producto #4673658=IfcGrid('0Z5ClTstDSLFuIAwXp7$_w',#18,'Default Grid',$,$,#4673657,#4673656,(#4673478,#4673487,#4673496,#4673505,#4673514,#4673523,#4673532,#4673541),(#4673550,#4673559,#4673568,#4673577,#4673586,#4673595,#4673604,#4673613),(#4673622,#4673631,#4673640,#4673649)): Failed to process shape
# Error procesando la geometría del producto #4673842=IfcGrid('17LjoIISPwIH8T5T7CdWVz',#18,'Default Grid',$,$,#4673841,#4673840,(#4673662,#4673671,#4673680,#4673689,#4673698,#4673707,#4673716,#4673725),(#4673734,#4673743,#4673752,#4673761,#4673770,#4673779,#4673788,#4673797),(#4673806,#4673815,#4673824,#4673833)): Failed to process shape
# Error procesando la geometría del producto #4674026=IfcGrid('1n6Yqq5gpdHwU1OIx1otlc',#18,'Default Grid',$,$,#4674025,#4674024,(#4673846,#4673855,#4673864,#4673873,#4673882,#4673891,#4673900,#4673909),(#4673918,#4673927,#4673936,#4673945,#4673954,#4673963,#4673972,#4673981),(#4673990,#4673999,#4674008,#4674017)): Failed to process shape
# Error procesando la geometría del producto #4674210=IfcGrid('0mA1T7OxKZcD$9Q1H19bY$',#18,'Default Grid',$,$,#4674209,#4674208,(#4674030,#4674039,#4674048,#4674057,#4674066,#4674075,#4674084,#4674093),(#4674102,#4674111,#4674120,#4674129,#4674138,#4674147,#4674156,#4674165),(#4674174,#4674183,#4674192,#4674201)): Failed to process shape
# Error procesando la geometría del producto #4674394=IfcGrid('2al8wFpXRD70A6SW6bjRnA',#18,'Default Grid',$,$,#4674393,#4674392,(#4674214,#4674223,#4674232,#4674241,#4674250,#4674259,#4674268,#4674277),(#4674286,#4674295,#4674304,#4674313,#4674322,#4674331,#4674340,#4674349),(#4674358,#4674367,#4674376,#4674385)): Failed to process shape
# Error procesando la geometría del producto #4674578=IfcGrid('10z0gzHM39pwoI56oIH_qd',#18,'Default Grid',$,$,#4674577,#4674576,(#4674398,#4674407,#4674416,#4674425,#4674434,#4674443,#4674452,#4674461),(#4674470,#4674479,#4674488,#4674497,#4674506,#4674515,#4674524,#4674533),(#4674542,#4674551,#4674560,#4674569)): Failed to process shape
# Error procesando la geometría del producto #4674762=IfcGrid('2O44mRNf1Jf7_ruPWuB7PD',#18,'Default Grid',$,$,#4674761,#4674760,(#4674582,#4674591,#4674600,#4674609,#4674618,#4674627,#4674636,#4674645),(#4674654,#4674663,#4674672,#4674681,#4674690,#4674699,#4674708,#4674717),(#4674726,#4674735,#4674744,#4674753)): Failed to process shape
# Error procesando la geometría del producto #4674946=IfcGrid('3biMdredTIa1EoLz$f2bwG',#18,'Default Grid',$,$,#4674945,#4674944,(#4674766,#4674775,#4674784,#4674793,#4674802,#4674811,#4674820,#4674829),(#4674838,#4674847,#4674856,#4674865,#4674874,#4674883,#4674892,#4674901),(#4674910,#4674919,#4674928,#4674937)): Failed to process shape
# El producto #4674950=IfcDistributionPort('2Yb7BymiJae3HRe6A4$Jgv',#18,'Port_1543468_1','Flow',$,#4674949,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4674955=IfcDistributionPort('2pzN5rSkZVEkQrjukRTHem',#18,'Port_1543468_2','Flow',$,#4674954,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4674960=IfcDistributionPort('3Uj1WhXpPWbjB3IOi58zTM',#18,'Port_1543468_3','Flow',$,#4674959,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4674965=IfcDistributionPort('1zcR6XYgB7ItaBVd5kSqi_',#18,'Port_1543469_1','Flow',$,#4674964,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4674970=IfcDistributionPort('3MWrdATA2pmlaGPkfLjsvf',#18,'Port_1543469_2','Flow',$,#4674969,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4674975=IfcDistributionPort('3Il6EsiONO$UDLB$bU1jx1',#18,'Port_1543469_3','Flow',$,#4674974,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4674980=IfcDistributionPort('1QVMj3Zl__t9CB3s_t5dK_',#18,'Port_1543470_1','Flow',$,#4674979,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4674985=IfcDistributionPort('0MSl7UBbC2JWOREvaEwEUI',#18,'Port_1543470_2','Flow',$,#4674984,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4674990=IfcDistributionPort('03cOFoXQXDuuuC13keHB7d',#18,'Port_1543470_3','Flow',$,#4674989,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4674995=IfcDistributionPort('1j7x_dQJ$qZinkf$C8x4cx',#18,'Port_1547509_1','Flow',$,#4674994,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675000=IfcDistributionPort('0KjSVaKV_EwewJWYP4Gjbf',#18,'Port_1547509_2','Flow',$,#4674999,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675005=IfcDistributionPort('3DIGdxi6ImQSMHGljvN7UZ',#18,'Port_1547509_3','Flow',$,#4675004,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675010=IfcDistributionPort('0Lo6xTItiVhhk_l3Wn7E6B',#18,'Port_1547509_4','Flow',$,#4675009,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675015=IfcDistributionPort('01K8X2rOy2nUHKgI5UbR0f',#18,'Port_1547509_5','Flow',$,#4675014,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675020=IfcDistributionPort('0qUP4pM9duXnoOAGUwari0',#18,'Port_1547509_6','Flow',$,#4675019,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675025=IfcDistributionPort('31zG6pEcesCIxvaTtP0J_m',#18,'Port_1547509_7','Flow',$,#4675024,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675030=IfcDistributionPort('2wdg6Lyb2H7U6I2ht2JCdE',#18,'Port_1547547_1','Flow',$,#4675029,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675035=IfcDistributionPort('2JkGbyNzkuqkyuIqvd2dkB',#18,'Port_1547547_2','Flow',$,#4675034,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675040=IfcDistributionPort('0QmRX0qVmIdssGe2WtOYUF',#18,'Port_1547547_3','Flow',$,#4675039,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675045=IfcDistributionPort('3tk_3McoUs4XL2818Zg3f2',#18,'Port_1547547_4','Flow',$,#4675044,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675050=IfcDistributionPort('0SU8_t6zrDS4h1zgqMbqS4',#18,'Port_1547547_5','Flow',$,#4675049,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675055=IfcDistributionPort('2CmVgITP5yd9dPOJ9GbLfX',#18,'Port_1547547_6','Flow',$,#4675054,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675060=IfcDistributionPort('21AK$FoPZjMb6WgJMThzKc',#18,'Port_1547547_7','Flow',$,#4675059,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675065=IfcDistributionPort('11dmlW8kU2H$ttucwgVDCo',#18,'Port_1547561_1','Flow',$,#4675064,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675070=IfcDistributionPort('1i7eIekBXIWJZeWGF8ayRB',#18,'Port_1547561_2','Flow',$,#4675069,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675075=IfcDistributionPort('33WLT06Sv0PIQwTAp9v0st',#18,'Port_1547561_3','Flow',$,#4675074,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675080=IfcDistributionPort('1KcRpgIxAMlPMZnpSfBR23',#18,'Port_1547561_4','Flow',$,#4675079,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675085=IfcDistributionPort('1ZfH9nSWhYlr$IIOX$lh4W',#18,'Port_1547561_5','Flow',$,#4675084,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675090=IfcDistributionPort('07PSvfmiN67MCHC8Nvia2H',#18,'Port_1547561_6','Flow',$,#4675089,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675095=IfcDistributionPort('2Oo7mwK3tWg9d8W$R4wPXq',#18,'Port_1547561_7','Flow',$,#4675094,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675100=IfcDistributionPort('2XJlrBMsAmsw_aWwgf2xGw',#18,'OutPort_1548573_1','Flow',$,#4675099,$,.SOURCE.) no tiene representación.
# El producto #4675105=IfcDistributionPort('0cXE2ci6XLmCd5fDBT23Qi',#18,'OutPort_1548573_8','Flow',$,#4675104,$,.SOURCE.) no tiene representación.
# El producto #4675110=IfcDistributionPort('2E2mI_8lBUymQTgCO2KZUe',#18,'OutPort_1548573_11','Flow',$,#4675109,$,.SOURCE.) no tiene representación.
# El producto #4675115=IfcDistributionPort('1fqZ4DaIRdMTJ9emwHlV7w',#18,'Port_1548573_12','Flow',$,#4675114,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675120=IfcDistributionPort('17n35U83y$$4TsRqEW3$o4',#18,'OutPort_1548573_13','Flow',$,#4675119,$,.SOURCE.) no tiene representación.
# El producto #4675125=IfcDistributionPort('3u8_WK6Kt8tr4P9fd7E6Pq',#18,'Port_1548573_14','Flow',$,#4675124,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675130=IfcDistributionPort('3MCCKHdtiF4INlo4Ec0abr',#18,'Port_3009421_1','Flow',$,#4675129,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675136=IfcDistributionPort('1wsjxIAPOYdDR9auuxAgJe',#18,'OutPort_1548573_15','Flow',$,#4675135,$,.SOURCE.) no tiene representación.
# El producto #4675141=IfcDistributionPort('0EzKVzbAyYBFq4W0Ja1jj5',#18,'OutPort_1548573_16','Flow',$,#4675140,$,.SOURCE.) no tiene representación.
# El producto #4675146=IfcDistributionPort('0Zmc0PsXesVU4_5d80OYB6',#18,'OutPort_1548573_17','Flow',$,#4675145,$,.SOURCE.) no tiene representación.
# El producto #4675151=IfcDistributionPort('28ioE5Eu2zUYkjCJKImUfv',#18,'Port_1548573_18','Flow',$,#4675150,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675156=IfcDistributionPort('3J2JrLQOYJZYkWJDM3wV$J',#18,'Port_3009388_1','Flow',$,#4675155,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675162=IfcDistributionPort('36B21$$QPNcKUrRHU8S9Dv',#18,'OutPort_1548573_19','Flow',$,#4675161,$,.SOURCE.) no tiene representación.
# El producto #4675167=IfcDistributionPort('0gZ0vAAebAGCwf8VFdPMLi',#18,'OutPort_1548573_20','Flow',$,#4675166,$,.SOURCE.) no tiene representación.
# El producto #4675172=IfcDistributionPort('2lATMla3cFkE9O0vn4rki$',#18,'OutPort_1548574_1','Flow',$,#4675171,$,.SOURCE.) no tiene representación.
# El producto #4675177=IfcDistributionPort('3Ct$pE_LkTi1HXco$ZHmQI',#18,'OutPort_1548574_8','Flow',$,#4675176,$,.SOURCE.) no tiene representación.
# El producto #4675182=IfcDistributionPort('3HjybvCDCecpJ6IlYtrDjd',#18,'OutPort_1548574_11','Flow',$,#4675181,$,.SOURCE.) no tiene representación.
# El producto #4675187=IfcDistributionPort('3rFwENOqVGnm31RLcYUvjM',#18,'Port_1548574_12','Flow',$,#4675186,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675192=IfcDistributionPort('3zLjmspkNc1uk3Ul6tdTYh',#18,'OutPort_1548574_13','Flow',$,#4675191,$,.SOURCE.) no tiene representación.
# El producto #4675197=IfcDistributionPort('0h5gOzo_oLoRrGyUxDARAh',#18,'Port_1548574_14','Flow',$,#4675196,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675202=IfcDistributionPort('3X1PtHNI1qhiBdltcQnTkb',#18,'Port_3009279_1','Flow',$,#4675201,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675208=IfcDistributionPort('2RU_0ophtqssoUURM52dG0',#18,'OutPort_1548574_15','Flow',$,#4675207,$,.SOURCE.) no tiene representación.
# El producto #4675213=IfcDistributionPort('1XSKwoN0$d4AhXb0Ipfk8Q',#18,'OutPort_1548574_16','Flow',$,#4675212,$,.SOURCE.) no tiene representación.
# El producto #4675218=IfcDistributionPort('1JFTwhquXXT$FA0AiSmF7q',#18,'OutPort_1548574_17','Flow',$,#4675217,$,.SOURCE.) no tiene representación.
# El producto #4675223=IfcDistributionPort('0w3HBRVLgCzBeUX3A1FWll',#18,'Port_1548574_18','Flow',$,#4675222,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675228=IfcDistributionPort('0hFG4_HPUVh$6w0mT1_tdV',#18,'Port_3009300_1','Flow',$,#4675227,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675234=IfcDistributionPort('1x4AmE$N6rXEYDxqT_Xhdw',#18,'OutPort_1548574_19','Flow',$,#4675233,$,.SOURCE.) no tiene representación.
# El producto #4675239=IfcDistributionPort('3IWIJ5$y5cGX4PD6hYdhdM',#18,'OutPort_1548574_20','Flow',$,#4675238,$,.SOURCE.) no tiene representación.
# El producto #4675244=IfcDistributionPort('3$R_ebQTIOvXQ$5KYvG6Zg',#18,'OutPort_1548575_1','Flow',$,#4675243,$,.SOURCE.) no tiene representación.
# El producto #4675249=IfcDistributionPort('2essJbZsLkrONHKZaehei0',#18,'OutPort_1548575_8','Flow',$,#4675248,$,.SOURCE.) no tiene representación.
# El producto #4675254=IfcDistributionPort('1g4mTDpMOFMAMaW52grzbR',#18,'OutPort_1548575_11','Flow',$,#4675253,$,.SOURCE.) no tiene representación.
# El producto #4675259=IfcDistributionPort('2fllG2zxQxEtfYvjPHkd89',#18,'Port_1548575_12','Flow',$,#4675258,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675264=IfcDistributionPort('3vkArcfat7EUHlbSVGYI9_',#18,'OutPort_1548575_13','Flow',$,#4675263,$,.SOURCE.) no tiene representación.
# El producto #4675269=IfcDistributionPort('2brZ5Ujfs26Qg67rCaNn4C',#18,'Port_1548575_14','Flow',$,#4675268,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675274=IfcDistributionPort('28_NOVJdbNGJoyH7C_jFOM',#18,'Port_3009522_1','Flow',$,#4675273,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675280=IfcDistributionPort('2a6yuEJFwfU9x4tt4oFIIQ',#18,'OutPort_1548575_15','Flow',$,#4675279,$,.SOURCE.) no tiene representación.
# El producto #4675285=IfcDistributionPort('0lZnc4KchxIf1fl7E9TBmg',#18,'OutPort_1548575_16','Flow',$,#4675284,$,.SOURCE.) no tiene representación.
# El producto #4675290=IfcDistributionPort('22SED83whSYqLAheENAIdi',#18,'OutPort_1548575_17','Flow',$,#4675289,$,.SOURCE.) no tiene representación.
# El producto #4675295=IfcDistributionPort('1ROBeutRwN8eM4dTqWdKV9',#18,'Port_1548575_18','Flow',$,#4675294,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675300=IfcDistributionPort('2Gpun4FzT4_kOedMqMtCgJ',#18,'Port_3009488_1','Flow',$,#4675299,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675306=IfcDistributionPort('0$YP$_bZpCwQtGmVvTFKow',#18,'OutPort_1548575_19','Flow',$,#4675305,$,.SOURCE.) no tiene representación.
# El producto #4675311=IfcDistributionPort('2xXJkq_xl1ntdTNHj5tAly',#18,'OutPort_1548575_20','Flow',$,#4675310,$,.SOURCE.) no tiene representación.
# El producto #4675316=IfcDistributionPort('3Bh$CD55jVxIQa3WyBereg',#18,'Port_1548576_1','Flow',$,#4675315,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675321=IfcDistributionPort('3Q2Ai$6saBA5_$4CRQvunK',#18,'Port_1548576_2','Flow',$,#4675320,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675326=IfcDistributionPort('1l4sfRzaka66DuIewzKO_c',#18,'Port_1548576_3','Flow',$,#4675325,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675331=IfcDistributionPort('3utFl1aUM$QM0FenI5r4st',#18,'Port_1548576_4','Flow',$,#4675330,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675336=IfcDistributionPort('2jfkve1i6Ml3owCrbxwhbG',#18,'Port_1548576_5','Flow',$,#4675335,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675341=IfcDistributionPort('3zAoqZWX5KMdgPYIsV054M',#18,'Port_1548576_6','Flow',$,#4675340,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675346=IfcDistributionPort('2H0kzHnLiLj8tEVnYyTy6I',#18,'Port_1548576_7','Flow',$,#4675345,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675351=IfcDistributionPort('1H4mmbfJWRBXZXjFOfkEvT',#18,'Port_1548577_1','Flow',$,#4675350,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675356=IfcDistributionPort('2KxsQl8UpnIM5lM4vUdT2t',#18,'Port_1548577_2','Flow',$,#4675355,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675361=IfcDistributionPort('2nxeC7HnfGlMxkQS5CFJ7Y',#18,'Port_1548577_3','Flow',$,#4675360,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675366=IfcDistributionPort('0wPXPLpf9cV3SilWtj4IUC',#18,'Port_1548577_4','Flow',$,#4675365,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675371=IfcDistributionPort('1FA3kQBJnPnwTvcwnw3gaR',#18,'Port_1548577_5','Flow',$,#4675370,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675376=IfcDistributionPort('1XsbzdC_JaSpmog1mWZX4w',#18,'Port_1548577_6','Flow',$,#4675375,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675381=IfcDistributionPort('2hIx50eZlog7SJ0AZ6OsEp',#18,'Port_1548577_7','Flow',$,#4675380,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675386=IfcDistributionPort('1XtQosiXL$RdD$lqbiS7gB',#18,'Port_1548578_1','Flow',$,#4675385,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675391=IfcDistributionPort('3lq8N15B9UtaprbJsIbb_Q',#18,'Port_1548578_2','Flow',$,#4675390,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675396=IfcDistributionPort('27stKnWyyTh_6N5G24V138',#18,'Port_1548578_3','Flow',$,#4675395,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675401=IfcDistributionPort('1fcGu8lf3oRfLIXRuebnbk',#18,'Port_1548578_4','Flow',$,#4675400,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675406=IfcDistributionPort('02QDVeRt0FWj7DKkZKgVYc',#18,'Port_1548578_5','Flow',$,#4675405,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675411=IfcDistributionPort('0XywtTEoANQZ7yEXN0A8do',#18,'Port_1548578_6','Flow',$,#4675410,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675416=IfcDistributionPort('2ZwF$wVmZj2Eg26kHE1fhf',#18,'Port_1548578_7','Flow',$,#4675415,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675421=IfcDistributionPort('05r2m9nFLQyn8yYIwCuZLK',#18,'OutPort_1553898_1','Flow',$,#4675420,$,.SOURCE.) no tiene representación.
# El producto #4675426=IfcDistributionPort('1u2kcSlSIN38eSlECQ5ndP',#18,'OutPort_1553898_8','Flow',$,#4675425,$,.SOURCE.) no tiene representación.
# El producto #4675431=IfcDistributionPort('2c04p0I$GiFgZmJmT9VLny',#18,'OutPort_1553898_11','Flow',$,#4675430,$,.SOURCE.) no tiene representación.
# El producto #4675436=IfcDistributionPort('2FHtqqGiR1CBHqpWP0o5sL',#18,'Port_1553898_12','Flow',$,#4675435,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675441=IfcDistributionPort('2t6uqXxghZBjsRxUQlA_u9',#18,'OutPort_1553898_13','Flow',$,#4675440,$,.SOURCE.) no tiene representación.
# El producto #4675446=IfcDistributionPort('2_IW82FwgbnOm6VkhV5IY4',#18,'Port_1553898_14','Flow',$,#4675445,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675451=IfcDistributionPort('0d956zFrDKoCh2Lo$9DaPI',#18,'Port_3000520_1','Flow',$,#4675450,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675457=IfcDistributionPort('33z2Ka24Z9d0T$WOBV3hOQ',#18,'OutPort_1553898_15','Flow',$,#4675456,$,.SOURCE.) no tiene representación.
# El producto #4675462=IfcDistributionPort('0PPqtLPW0lHrdLm$Sz$nal',#18,'OutPort_1553898_16','Flow',$,#4675461,$,.SOURCE.) no tiene representación.
# El producto #4675467=IfcDistributionPort('1P80nazn0VrZEvbtmFjo9M',#18,'OutPort_1553898_17','Flow',$,#4675466,$,.SOURCE.) no tiene representación.
# El producto #4675472=IfcDistributionPort('3eayRQuWT5ym5IHgETGMY5',#18,'Port_1553898_18','Flow',$,#4675471,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675477=IfcDistributionPort('2WguSV$6Cf3gy_8nYF55RC',#18,'Port_3000454_1','Flow',$,#4675476,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675483=IfcDistributionPort('2G6pu5nCCwLOIBD4mnRePE',#18,'OutPort_1553898_19','Flow',$,#4675482,$,.SOURCE.) no tiene representación.
# El producto #4675488=IfcDistributionPort('1XwDqhZ2o7IakOwH$xzGvH',#18,'OutPort_1553898_20','Flow',$,#4675487,$,.SOURCE.) no tiene representación.
# El producto #4675493=IfcDistributionPort('0LMxiwl9ImdfhJq1EpgEuX',#18,'OutPort_1553899_1','Flow',$,#4675492,$,.SOURCE.) no tiene representación.
# El producto #4675498=IfcDistributionPort('2iBhTbzUFYlMD7b3fzh6DP',#18,'OutPort_1553899_8','Flow',$,#4675497,$,.SOURCE.) no tiene representación.
# El producto #4675503=IfcDistributionPort('17iB2iAaiqQOJJJyMuE4Ii',#18,'OutPort_1553899_11','Flow',$,#4675502,$,.SOURCE.) no tiene representación.
# El producto #4675508=IfcDistributionPort('0k9craaGnv611e0BSvVYAW',#18,'Port_1553899_12','Flow',$,#4675507,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675513=IfcDistributionPort('12qE$8LNC6PsIZDDWpl8Jj',#18,'OutPort_1553899_13','Flow',$,#4675512,$,.SOURCE.) no tiene representación.
# El producto #4675518=IfcDistributionPort('1rqXxm8n2XAWEAsZPxfoGH',#18,'Port_1553899_14','Flow',$,#4675517,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675523=IfcDistributionPort('3BDppjB7ZCmJAnR60_0B3z',#18,'Port_3000647_1','Flow',$,#4675522,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675529=IfcDistributionPort('1eN8hSVVCKxand1G$6hMVW',#18,'OutPort_1553899_15','Flow',$,#4675528,$,.SOURCE.) no tiene representación.
# El producto #4675534=IfcDistributionPort('1ywAxY$3BTHwwOC_BjstP5',#18,'OutPort_1553899_16','Flow',$,#4675533,$,.SOURCE.) no tiene representación.
# El producto #4675539=IfcDistributionPort('1Rhq4CUecqeUk2ADejzeye',#18,'OutPort_1553899_17','Flow',$,#4675538,$,.SOURCE.) no tiene representación.
# El producto #4675544=IfcDistributionPort('0IZ2hPIGm0PkUwAHprysJO',#18,'Port_1553899_18','Flow',$,#4675543,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675549=IfcDistributionPort('2f4xp2ajS192YQYhinYQkE',#18,'Port_3000605_1','Flow',$,#4675548,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675555=IfcDistributionPort('3evk$WJMhf86k3CCs6KhiG',#18,'OutPort_1553899_19','Flow',$,#4675554,$,.SOURCE.) no tiene representación.
# El producto #4675560=IfcDistributionPort('1z_xsl2_h_tqKW4OOSOQNe',#18,'OutPort_1553899_20','Flow',$,#4675559,$,.SOURCE.) no tiene representación.
# El producto #4675565=IfcDistributionPort('0CaHfN5Lfs5Gz$zVuJuTik',#18,'Port_1553900_1','Flow',$,#4675564,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675570=IfcDistributionPort('2NVOIkDl62ElDJmBV0WjdQ',#18,'Port_1553900_8','Flow',$,#4675569,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675575=IfcDistributionPort('2wyjpg61uLSxr5QrIH2Q5_',#18,'Port_1553900_11','Flow',$,#4675574,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675580=IfcDistributionPort('3aqoxaXblCb_j2kzJYVYRG',#18,'Port_1553900_12','Flow',$,#4675579,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675585=IfcDistributionPort('3wV7DCi0rOTWw4tXoNIOyn',#18,'Port_1553900_13','Flow',$,#4675584,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675590=IfcDistributionPort('05s7sl2zQAV5$8NA8c2LLG',#18,'InPort_3000359_1','Flow',$,#4675589,$,.SINK.) no tiene representación.
# El producto #4675595=IfcDistributionPort('06HdE2bPL8kBxvZCsQ$zIW',#18,'OutPort_1553900_14','Flow',$,#4675594,$,.SOURCE.) no tiene representación.
# El producto #4675601=IfcDistributionPort('2z$bi6sU2x073t4EOg9jeX',#18,'Port_1553900_15','Flow',$,#4675600,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675606=IfcDistributionPort('1_zxTmceanDBTklaTXahMY',#18,'Port_1553900_16','Flow',$,#4675605,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675611=IfcDistributionPort('1WUmAaoUeQhxGbHYTzDzuY',#18,'Port_1553900_17','Flow',$,#4675610,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675616=IfcDistributionPort('32bHxoIapHUwL1nQlg8pJf',#18,'Port_1553900_18','Flow',$,#4675615,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675621=IfcDistributionPort('22q7pQEXf67MSyDJb2zD$U',#18,'Port_3002336_1','Flow',$,#4675620,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675627=IfcDistributionPort('2yJpoEEdh_qOlw6PThvb7z',#18,'Port_1553900_19','Flow',$,#4675626,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675632=IfcDistributionPort('0M271Gbm8g0jLVytIhbEuZ',#18,'Port_1553900_20','Flow',$,#4675631,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675637=IfcDistributionPort('2XUr_0oVVsP$$9hfTkTEnB',#18,'Port_1553901_1','Flow',$,#4675636,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675642=IfcDistributionPort('1exFcoPH$pAtVMqOYU2LFN',#18,'Port_1553901_2','Flow',$,#4675641,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675647=IfcDistributionPort('1hHBIdTBAenUs7OggZ7Xcu',#18,'Port_1553901_3','Flow',$,#4675646,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675652=IfcDistributionPort('1HxnBqCuQnrClH9TiE7NyF',#18,'Port_1553901_4','Flow',$,#4675651,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675657=IfcDistributionPort('1F2qQeIAGuxHEaczgY5BSm',#18,'Port_1553901_5','Flow',$,#4675656,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675662=IfcDistributionPort('1FsL3yMeeJCKwVT2GTHWgD',#18,'Port_1553901_6','Flow',$,#4675661,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675667=IfcDistributionPort('232Igiuj3KVBKxS1dHqywl',#18,'Port_1553901_7','Flow',$,#4675666,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675672=IfcDistributionPort('0z9S$i_R9SGGV2ZzJxReYB',#18,'Port_1553902_1','Flow',$,#4675671,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675677=IfcDistributionPort('2_nqNUuCz29KzMbfkKkDqp',#18,'Port_1553902_2','Flow',$,#4675676,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675682=IfcDistributionPort('1yJbqiTnGWfyUzUGHvl0PT',#18,'Port_1553902_3','Flow',$,#4675681,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675687=IfcDistributionPort('0DX8KFFL0HbElxV$PBma5d',#18,'Port_1553902_4','Flow',$,#4675686,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675692=IfcDistributionPort('1D3ZjcFa2tDuwjj0hHA8V8',#18,'Port_1553902_5','Flow',$,#4675691,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675697=IfcDistributionPort('2qRbEtDVls5Cg29LyObxF9',#18,'Port_1553902_6','Flow',$,#4675696,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675702=IfcDistributionPort('2Mc6EQGrfKmnXQpcnZHFxr',#18,'Port_1553902_7','Flow',$,#4675701,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675707=IfcDistributionPort('3x$03sq0Qyihbs8xCCv_K8',#18,'Port_1553903_1','Flow',$,#4675706,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675712=IfcDistributionPort('2msXQa7hArnbCbCQJFZsqB',#18,'Port_1553903_2','Flow',$,#4675711,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675717=IfcDistributionPort('3frGk91tgwFxX5Hh1L3rhB',#18,'Port_1553903_3','Flow',$,#4675716,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675722=IfcDistributionPort('0l5xeuYy0eeJRO$cGfKPTs',#18,'Port_1553903_4','Flow',$,#4675721,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675727=IfcDistributionPort('2KyC$AhjmRSquiMWEU5iRV',#18,'Port_1553903_5','Flow',$,#4675726,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675732=IfcDistributionPort('0QQNdJAsMf7Q1bVKs_zotd',#18,'Port_1553903_6','Flow',$,#4675731,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675737=IfcDistributionPort('35fO1B7KvpKcE5jykWAEg1',#18,'Port_1553903_7','Flow',$,#4675736,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675742=IfcDistributionPort('2tn2_UUAM0W2$Ao_Y3TZgR',#18,'OutPort_1555779_1','Flow',$,#4675741,$,.SOURCE.) no tiene representación.
# El producto #4675747=IfcDistributionPort('1mJHkgyp_IH7_gJiND2RFg',#18,'OutPort_1555779_8','Flow',$,#4675746,$,.SOURCE.) no tiene representación.
# El producto #4675752=IfcDistributionPort('027_9VlB0V3VYdNuiuPoAg',#18,'OutPort_1555779_11','Flow',$,#4675751,$,.SOURCE.) no tiene representación.
# El producto #4675757=IfcDistributionPort('16TgshRibN0X7ebMpzMzNJ',#18,'Port_1555779_12','Flow',$,#4675756,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675762=IfcDistributionPort('3UL4jy7q0zVOHVyUxtew4G',#18,'OutPort_1555779_13','Flow',$,#4675761,$,.SOURCE.) no tiene representación.
# El producto #4675767=IfcDistributionPort('1CPQxYYS75y0$8CB_bksEj',#18,'OutPort_1555779_14','Flow',$,#4675766,$,.SOURCE.) no tiene representación.
# El producto #4675772=IfcDistributionPort('3RjaHmZitnoK_w0h7vjDlF',#18,'OutPort_1555779_15','Flow',$,#4675771,$,.SOURCE.) no tiene representación.
# El producto #4675777=IfcDistributionPort('22n0ns5RrCmSpuzGv_XlzA',#18,'OutPort_1555779_16','Flow',$,#4675776,$,.SOURCE.) no tiene representación.
# El producto #4675782=IfcDistributionPort('0As3QT$oxZzCvA9i6ZXOGx',#18,'OutPort_1555779_17','Flow',$,#4675781,$,.SOURCE.) no tiene representación.
# El producto #4675787=IfcDistributionPort('1tIOPtRKLsl_bMGker7Hjx',#18,'OutPort_1555779_18','Flow',$,#4675786,$,.SOURCE.) no tiene representación.
# El producto #4675792=IfcDistributionPort('2JvBmLkOCBX02tzqmE_KMq',#18,'OutPort_1555779_19','Flow',$,#4675791,$,.SOURCE.) no tiene representación.
# El producto #4675797=IfcDistributionPort('1mG6BU_eVTnQaE2rCjn5BF',#18,'OutPort_1555779_20','Flow',$,#4675796,$,.SOURCE.) no tiene representación.
# El producto #4675802=IfcDistributionPort('1FX3POQhGrejHKSGCJz0uo',#18,'OutPort_1555780_1','Flow',$,#4675801,$,.SOURCE.) no tiene representación.
# El producto #4675807=IfcDistributionPort('1uuapp_Trsm0iewTaWNcuH',#18,'OutPort_1555780_8','Flow',$,#4675806,$,.SOURCE.) no tiene representación.
# El producto #4675812=IfcDistributionPort('1v6ik4dYJQwuTfqJact8Qu',#18,'OutPort_1555780_11','Flow',$,#4675811,$,.SOURCE.) no tiene representación.
# El producto #4675817=IfcDistributionPort('0BZY0Bae2R8otKm0yleBuJ',#18,'Port_1555780_12','Flow',$,#4675816,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675822=IfcDistributionPort('2looFwQxS$oSYyLehQxSsP',#18,'OutPort_1555780_13','Flow',$,#4675821,$,.SOURCE.) no tiene representación.
# El producto #4675827=IfcDistributionPort('2uL4anmwckXdSdYaUQs6qx',#18,'Port_1555780_14','Flow',$,#4675826,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675832=IfcDistributionPort('1uG82y56MuYuB0HPwMBfLG',#18,'Port_3002535_1','Flow',$,#4675831,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675838=IfcDistributionPort('3ENcAqvXy32AFbo6mNfz6z',#18,'OutPort_1555780_15','Flow',$,#4675837,$,.SOURCE.) no tiene representación.
# El producto #4675843=IfcDistributionPort('3bvj$pcYq$sKt3yPcOnqQe',#18,'OutPort_1555780_16','Flow',$,#4675842,$,.SOURCE.) no tiene representación.
# El producto #4675848=IfcDistributionPort('3kGfQfwfW58gqnjt8Wbj_4',#18,'OutPort_1555780_17','Flow',$,#4675847,$,.SOURCE.) no tiene representación.
# El producto #4675853=IfcDistributionPort('1nGBwcLtzshGm7DJA4Wvfa',#18,'Port_1555780_18','Flow',$,#4675852,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675858=IfcDistributionPort('2VaIN8eQsP2CIFpZlCt2lp',#18,'Port_3002453_1','Flow',$,#4675857,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675864=IfcDistributionPort('0MYB69XOx11fr1J3fGvCq9',#18,'OutPort_1555780_19','Flow',$,#4675863,$,.SOURCE.) no tiene representación.
# El producto #4675869=IfcDistributionPort('1gWIHr6W_cEdkKHjpcJh5I',#18,'OutPort_1555780_20','Flow',$,#4675868,$,.SOURCE.) no tiene representación.
# El producto #4675874=IfcDistributionPort('1PI7TJvAdDKYugphyhejjA',#18,'OutPort_1555781_1','Flow',$,#4675873,$,.SOURCE.) no tiene representación.
# El producto #4675879=IfcDistributionPort('1kCFZgRDG3m4qL3NciovoG',#18,'OutPort_1555781_8','Flow',$,#4675878,$,.SOURCE.) no tiene representación.
# El producto #4675884=IfcDistributionPort('2U81Xw9GPpASUjnR0yA$lu',#18,'OutPort_1555781_11','Flow',$,#4675883,$,.SOURCE.) no tiene representación.
# El producto #4675889=IfcDistributionPort('08Y1G_g4Nef_in_RPMdeIy',#18,'Port_1555781_12','Flow',$,#4675888,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675894=IfcDistributionPort('0JsQ2RLaJN2o7vnRLdov9p',#18,'OutPort_1555781_13','Flow',$,#4675893,$,.SOURCE.) no tiene representación.
# El producto #4675899=IfcDistributionPort('361nwi5dr_M3PnFY_gnigo',#18,'OutPort_1555781_14','Flow',$,#4675898,$,.SOURCE.) no tiene representación.
# El producto #4675904=IfcDistributionPort('0DBmUSoxIUsb8nKs$58YZA',#18,'OutPort_1555781_15','Flow',$,#4675903,$,.SOURCE.) no tiene representación.
# El producto #4675909=IfcDistributionPort('2E6YD4ZlqBHkibgZ7cnOay',#18,'OutPort_1555781_16','Flow',$,#4675908,$,.SOURCE.) no tiene representación.
# El producto #4675914=IfcDistributionPort('3L2NsJ7tCF$PPnzronO$1T',#18,'OutPort_1555781_17','Flow',$,#4675913,$,.SOURCE.) no tiene representación.
# El producto #4675919=IfcDistributionPort('0Zy7_kKABMLBWgBvPt28$8',#18,'OutPort_1555781_18','Flow',$,#4675918,$,.SOURCE.) no tiene representación.
# El producto #4675924=IfcDistributionPort('3BH$WlLSKMbrfC2J1PjrXc',#18,'OutPort_1555781_19','Flow',$,#4675923,$,.SOURCE.) no tiene representación.
# El producto #4675929=IfcDistributionPort('3wnhHIZx2jVwQo0z8Ydk$e',#18,'OutPort_1555781_20','Flow',$,#4675928,$,.SOURCE.) no tiene representación.
# El producto #4675934=IfcDistributionPort('1AciDEWM6PovizYgvJhe2z',#18,'Port_1555782_1','Flow',$,#4675933,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675939=IfcDistributionPort('0iBoP90R$JCpDcgJ_LST0h',#18,'Port_1555782_2','Flow',$,#4675938,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675944=IfcDistributionPort('19Kjdc6o7gcV98iOw1mu3n',#18,'Port_1555782_3','Flow',$,#4675943,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675949=IfcDistributionPort('1BwtDd3WDY5nQit1LaS4tD',#18,'Port_1555782_4','Flow',$,#4675948,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675954=IfcDistributionPort('334db18kQdxxr0GFY73IrV',#18,'Port_1555782_5','Flow',$,#4675953,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675959=IfcDistributionPort('2UwgQcXfWCXGkUsDVdYsH5',#18,'Port_1555782_6','Flow',$,#4675958,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675964=IfcDistributionPort('119$G04NmXpxH7ZGg6O8sP',#18,'Port_1555782_7','Flow',$,#4675963,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675969=IfcDistributionPort('0WTK62U6fiW5Nw5uUo47Fa',#18,'Port_1555783_1','Flow',$,#4675968,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675974=IfcDistributionPort('2sMsHgQKH0VxPXPnK8WAzs',#18,'Port_1555783_2','Flow',$,#4675973,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675979=IfcDistributionPort('1AdicMQ7_vXQUbqDrFsvTW',#18,'Port_1555783_3','Flow',$,#4675978,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675984=IfcDistributionPort('1g0trrKkTnrwEzKA6XUisv',#18,'Port_1555783_4','Flow',$,#4675983,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675989=IfcDistributionPort('0d04OT69qJzw54fzuSt1mH',#18,'Port_1555783_5','Flow',$,#4675988,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675994=IfcDistributionPort('1VwuMPtj91GyxJ$iAkhcjw',#18,'Port_1555783_6','Flow',$,#4675993,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4675999=IfcDistributionPort('3fxZXS53wBaIJWtvzrw0rH',#18,'Port_1555783_7','Flow',$,#4675998,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676004=IfcDistributionPort('1XR0KN0nRLxPKR$xnSb_zN',#18,'Port_1555784_1','Flow',$,#4676003,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676009=IfcDistributionPort('09gmdQFt6yX3ReyGsbrNA$',#18,'Port_1555784_2','Flow',$,#4676008,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676014=IfcDistributionPort('20XNgNO0QfAVqFub8vKveV',#18,'Port_1555784_3','Flow',$,#4676013,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676019=IfcDistributionPort('2chYofSm6iILqRUlxLdf2o',#18,'Port_1555784_4','Flow',$,#4676018,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676024=IfcDistributionPort('2gkY2nRj7No6$JUwCcpWMn',#18,'Port_1555784_5','Flow',$,#4676023,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676029=IfcDistributionPort('32ejbX4gZB4r7rrjNQd58J',#18,'Port_1555784_6','Flow',$,#4676028,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676034=IfcDistributionPort('0ctrvlvydqFrnR_91iChv8',#18,'Port_1555784_7','Flow',$,#4676033,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676039=IfcDistributionPort('2Vixmgaw7XDpjk5d4vDVbG',#18,'OutPort_1556179_1','Flow',$,#4676038,$,.SOURCE.) no tiene representación.
# El producto #4676044=IfcDistributionPort('2V9lUY71b4UqKgJGRWaP_H',#18,'OutPort_1556179_8','Flow',$,#4676043,$,.SOURCE.) no tiene representación.
# El producto #4676049=IfcDistributionPort('3b_CNT_Cx3BwJojRkse_TZ',#18,'OutPort_1556179_11','Flow',$,#4676048,$,.SOURCE.) no tiene representación.
# El producto #4676054=IfcDistributionPort('1CG5c5D4V35qVhYW_s0E9f',#18,'Port_1556179_12','Flow',$,#4676053,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676059=IfcDistributionPort('0cBXdksT2CwX_A03Bl5ryB',#18,'OutPort_1556179_13','Flow',$,#4676058,$,.SOURCE.) no tiene representación.
# El producto #4676064=IfcDistributionPort('0ne4$_PJnXLb2kHtilqLM$',#18,'Port_1556179_14','Flow',$,#4676063,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676069=IfcDistributionPort('1P8evR56ZDYTB3T9OdOX7A',#18,'Port_3193115_1','Flow',$,#4676068,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676075=IfcDistributionPort('1jNq7_jmmnBvsJWWCWlMLI',#18,'OutPort_1556179_15','Flow',$,#4676074,$,.SOURCE.) no tiene representación.
# El producto #4676080=IfcDistributionPort('1nf6S8CdKy4RkcaASY9Uy$',#18,'OutPort_1556179_16','Flow',$,#4676079,$,.SOURCE.) no tiene representación.
# El producto #4676085=IfcDistributionPort('3drQYhGToBjQCFAOSepEpl',#18,'OutPort_1556179_17','Flow',$,#4676084,$,.SOURCE.) no tiene representación.
# El producto #4676090=IfcDistributionPort('3LJ36QOLQmMhgAPyurhLX2',#18,'Port_1556179_18','Flow',$,#4676089,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676095=IfcDistributionPort('3mb4Is3nbMV$xFx85KE4r_',#18,'Port_3193095_1','Flow',$,#4676094,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676101=IfcDistributionPort('1fNnPhQ0C3dKNKh7aAKbo0',#18,'OutPort_1556179_19','Flow',$,#4676100,$,.SOURCE.) no tiene representación.
# El producto #4676106=IfcDistributionPort('1uA12AjTkf63gXfj9$pU5X',#18,'OutPort_1556179_20','Flow',$,#4676105,$,.SOURCE.) no tiene representación.
# El producto #4676111=IfcDistributionPort('3GRQyBKbm4LroPjJwdvnf$',#18,'OutPort_1556180_1','Flow',$,#4676110,$,.SOURCE.) no tiene representación.
# El producto #4676116=IfcDistributionPort('1UT888mDxtskK4LtDHMddM',#18,'OutPort_1556180_8','Flow',$,#4676115,$,.SOURCE.) no tiene representación.
# El producto #4676121=IfcDistributionPort('2edzbE04kDrewz2gR1uOXW',#18,'OutPort_1556180_11','Flow',$,#4676120,$,.SOURCE.) no tiene representación.
# El producto #4676126=IfcDistributionPort('08mlG50CPveUImBn6SXLhE',#18,'Port_1556180_12','Flow',$,#4676125,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676131=IfcDistributionPort('3_kYrZOx3QjdeWzGsxPF1k',#18,'OutPort_1556180_13','Flow',$,#4676130,$,.SOURCE.) no tiene representación.
# El producto #4676136=IfcDistributionPort('1TV3rTkBjVZV_Hv3Wyv_WU',#18,'Port_1556180_14','Flow',$,#4676135,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676141=IfcDistributionPort('38H$rhkyMp2TOf472AlWbg',#18,'Port_3010280_1','Flow',$,#4676140,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676147=IfcDistributionPort('1emQh_gLF6W2rGG5NUdZ9T',#18,'OutPort_1556180_15','Flow',$,#4676146,$,.SOURCE.) no tiene representación.
# El producto #4676152=IfcDistributionPort('1SmRlxq$sGccou0$aH3QR8',#18,'OutPort_1556180_16','Flow',$,#4676151,$,.SOURCE.) no tiene representación.
# El producto #4676157=IfcDistributionPort('0jEUZeWzWv7cvfStIKFwql',#18,'OutPort_1556180_17','Flow',$,#4676156,$,.SOURCE.) no tiene representación.
# El producto #4676162=IfcDistributionPort('0ylfy24x5eNiF3uWL6TSU6',#18,'Port_1556180_18','Flow',$,#4676161,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676167=IfcDistributionPort('0bQTr6uSc2YEf2r1YhAWIX',#18,'Port_3010252_1','Flow',$,#4676166,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676173=IfcDistributionPort('2UjHeZLXelCz7cmdwIXHW_',#18,'OutPort_1556180_19','Flow',$,#4676172,$,.SOURCE.) no tiene representación.
# El producto #4676178=IfcDistributionPort('35CLm81BeeBZmPkCAKdnEl',#18,'OutPort_1556180_20','Flow',$,#4676177,$,.SOURCE.) no tiene representación.
# El producto #4676183=IfcDistributionPort('0JcKYm3gtUPlD3IE5YuD93',#18,'OutPort_1556181_1','Flow',$,#4676182,$,.SOURCE.) no tiene representación.
# El producto #4676188=IfcDistributionPort('0651eIMlFp6VDjbj_$HQkl',#18,'OutPort_1556181_8','Flow',$,#4676187,$,.SOURCE.) no tiene representación.
# El producto #4676193=IfcDistributionPort('1ar0cEBJ8V5CJhgSGS5MXZ',#18,'OutPort_1556181_11','Flow',$,#4676192,$,.SOURCE.) no tiene representación.
# El producto #4676198=IfcDistributionPort('3fQyRk8ymd1j7H93OWhboU',#18,'Port_1556181_12','Flow',$,#4676197,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676203=IfcDistributionPort('1Jr$wYrtTmqpe8V_2DJvyV',#18,'OutPort_1556181_13','Flow',$,#4676202,$,.SOURCE.) no tiene representación.
# El producto #4676208=IfcDistributionPort('06S03j_PqXWhUyY82ihYEj',#18,'Port_1556181_14','Flow',$,#4676207,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676213=IfcDistributionPort('33lPfi607JuO4w5iGikxlT',#18,'Port_3193236_1','Flow',$,#4676212,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676219=IfcDistributionPort('3WEML6k5CsNxiXhwCT5gbw',#18,'OutPort_1556181_15','Flow',$,#4676218,$,.SOURCE.) no tiene representación.
# El producto #4676224=IfcDistributionPort('1Dek6Pu4nv1kAi6iftLCuX',#18,'OutPort_1556181_16','Flow',$,#4676223,$,.SOURCE.) no tiene representación.
# El producto #4676229=IfcDistributionPort('0LdqtsgnpbtiQp8kqVd6Sl',#18,'OutPort_1556181_17','Flow',$,#4676228,$,.SOURCE.) no tiene representación.
# El producto #4676234=IfcDistributionPort('0QQ$BFQ0CRhMixmu7MhIXm',#18,'Port_1556181_18','Flow',$,#4676233,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676239=IfcDistributionPort('1kaJOXokjgB_OMuXQDAWWq',#18,'Port_3193155_1','Flow',$,#4676238,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676245=IfcDistributionPort('33LKRUDhV0vadLKsMTVGwX',#18,'OutPort_1556181_19','Flow',$,#4676244,$,.SOURCE.) no tiene representación.
# El producto #4676250=IfcDistributionPort('0EjxMt3uFJDaERBFotnucM',#18,'OutPort_1556181_20','Flow',$,#4676249,$,.SOURCE.) no tiene representación.
# El producto #4676255=IfcDistributionPort('2mwwdzMWrs5R1uEjwAVtAj',#18,'Port_1556182_1','Flow',$,#4676254,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676260=IfcDistributionPort('1nNw4Wtnalm5uJp6LQ21Vn',#18,'Port_1556182_2','Flow',$,#4676259,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676265=IfcDistributionPort('3wSJAm9fENMdmENKBAZBZG',#18,'Port_1556182_3','Flow',$,#4676264,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676270=IfcDistributionPort('3ag0noImpnrciA5HtAxI4d',#18,'Port_1556182_4','Flow',$,#4676269,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676275=IfcDistributionPort('0kBclGtexPe2SpdL$7VJIt',#18,'Port_1556182_5','Flow',$,#4676274,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676280=IfcDistributionPort('28oBfWyd6HwbtXzgEZ6IA$',#18,'Port_1556182_6','Flow',$,#4676279,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676285=IfcDistributionPort('0KoOGqv$mbxXGyMRtksWYo',#18,'Port_1556182_7','Flow',$,#4676284,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676290=IfcDistributionPort('3cgFOa1TOFwxVeTkC$GzHq',#18,'Port_1556183_1','Flow',$,#4676289,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676295=IfcDistributionPort('0iz3nPdZD48LKktXQnyW9i',#18,'Port_1556183_2','Flow',$,#4676294,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676300=IfcDistributionPort('1Nksj7rJdmDEgFUZaI1wVO',#18,'Port_1556183_3','Flow',$,#4676299,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676305=IfcDistributionPort('14YkyXT_TU10SA7yBhZgY1',#18,'Port_1556183_4','Flow',$,#4676304,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676310=IfcDistributionPort('1UqdJhcfAgQOJ4TIou8wrf',#18,'Port_1556183_5','Flow',$,#4676309,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676315=IfcDistributionPort('17xRxms2YOOTSsq71cwCFZ',#18,'Port_1556183_6','Flow',$,#4676314,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676320=IfcDistributionPort('1SFhfPRN47U8UQCzdG8SOE',#18,'Port_1556183_7','Flow',$,#4676319,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676325=IfcDistributionPort('3foyGevW9RHqEczfgrrAh2',#18,'Port_1556184_1','Flow',$,#4676324,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676330=IfcDistributionPort('01MYOX6Q_u3PA1kw9$$15j',#18,'Port_1556184_2','Flow',$,#4676329,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676335=IfcDistributionPort('2VNmtxmNo0In_zMg9nRHuo',#18,'Port_1556184_3','Flow',$,#4676334,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676340=IfcDistributionPort('3stryD1$XUVpyBNltTa1nQ',#18,'Port_1556184_4','Flow',$,#4676339,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676345=IfcDistributionPort('3ruR9KqzuMO5VNbjjyQMSa',#18,'Port_1556184_5','Flow',$,#4676344,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676350=IfcDistributionPort('3oCpprN6vYPpKLN0iJ2$P1',#18,'Port_1556184_6','Flow',$,#4676349,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676355=IfcDistributionPort('0lx1qjQDbjIpOy7$X20gqS',#18,'Port_1556184_7','Flow',$,#4676354,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676360=IfcDistributionPort('0F5l3xrsNg$q51D2Y$fVJ5',#18,'OutPort_1556685_1','Flow',$,#4676359,$,.SOURCE.) no tiene representación.
# El producto #4676365=IfcDistributionPort('1qUVYeaIguDvKOlbOSFiD2',#18,'OutPort_1556685_8','Flow',$,#4676364,$,.SOURCE.) no tiene representación.
# El producto #4676370=IfcDistributionPort('3pndp$258NQID2i32UVZGd',#18,'OutPort_1556685_11','Flow',$,#4676369,$,.SOURCE.) no tiene representación.
# El producto #4676375=IfcDistributionPort('1Zo69hYgsdTN3bj_koLxML',#18,'Port_1556685_12','Flow',$,#4676374,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676380=IfcDistributionPort('3WxGWieAVnLW12SNBRjarf',#18,'OutPort_1556685_13','Flow',$,#4676379,$,.SOURCE.) no tiene representación.
# El producto #4676385=IfcDistributionPort('2iozBMAHi_e6EnBdZMTjDb',#18,'Port_1556685_14','Flow',$,#4676384,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676390=IfcDistributionPort('2TTtKPtH3anrlmPvnzQXwY',#18,'Port_3008778_1','Flow',$,#4676389,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4676396=IfcDistributionPort('2jeWuJfRa2QZBsvehOLSIn',#18,'OutPort_1556685_15','Flow',$,#4676395,$,.SOURCE.) no tiene representación.
# El producto #4676401=IfcDistributionPort('3dmiXksIw2BVXlh6d0VakN',#18,'OutPort_1556685_16','Flow',$,#4676400,$,.SOURCE.) no tiene representación.
# El producto #4676406=IfcDistributionPort('1xN7vWXwEui6p$9KP06Ot5',#18,'OutPort_1556685_17','Flow',$,#4676405,$,.SOURCE.) no tiene representación.
# ...
# El producto #4693294=IfcDistributionPort('0VHEhYKDi$Vsc3arx1sRK4',#18,'Port_3403442_19','Flow',$,#4693293,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693301=IfcDistributionPort('2zZNklCjejG5drMdCdqbLf',#18,'Port_3403694_12','Flow',$,#4693300,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693308=IfcDistributionPort('3$xtNLU7jkCOUAzQtdxD$i',#18,'Port_3403694_13','Flow',$,#4693307,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693315=IfcDistributionPort('2bfXH$P2b4ufP11vwYtF8q',#18,'Port_3403694_14','Flow',$,#4693314,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693322=IfcDistributionPort('0eNQIejMrQqOeocosZfH5k',#18,'Port_3403694_15','Flow',$,#4693321,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693329=IfcDistributionPort('3mggmDlG6PkpOaaP9KSoof',#18,'Port_3403694_16','Flow',$,#4693328,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693336=IfcDistributionPort('1nj9YsERWrQQmJjrEbxN$m',#18,'Port_3403694_17','Flow',$,#4693335,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693343=IfcDistributionPort('20N3Sr$NRXRXvZ9y3KtDUO',#18,'Port_3403694_18','Flow',$,#4693342,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693350=IfcDistributionPort('3ngRXgn4ZvHpYUT0J9ewSj',#18,'Port_3403694_19','Flow',$,#4693349,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693357=IfcDistributionPort('1$C_rmo0gh9545tFiqqh$f',#18,'Port_3492047_1','Flow',$,#4693356,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693364=IfcDistributionPort('24t1k1dXai81SDaPJswX_e',#18,'Port_3492047_2','Flow',$,#4693363,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693371=IfcDistributionPort('0oE23Ezl7RN9Pw8wIIFe_2',#18,'Port_3508435_1','Flow',$,#4693370,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693378=IfcDistributionPort('3KKjZaNXqjOLU5aGNfeBQX',#18,'Port_3508435_2','Flow',$,#4693377,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693385=IfcDistributionPort('15_s2FSkBBwzA7rKYTQjt$',#18,'Port_3508447_1','Flow',$,#4693384,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693392=IfcDistributionPort('3jvRfFW5Mx_XiYww0O8UOL',#18,'Port_3508447_2','Flow',$,#4693391,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693397=IfcDistributionPort('12$I320FG$FntBmw2eqI9d',#18,'Port_4077727_1','Flow',$,#4693396,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693402=IfcDistributionPort('0hV$sDhaQ$1UUbkO_8bEfe',#18,'Port_4077727_2','Flow',$,#4693401,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693407=IfcDistributionPort('3I910hkQnD5AYhLIbDEsJl',#18,'Port_4077727_3','Flow',$,#4693406,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693412=IfcDistributionPort('1U0ofNMjAUViyr$5vtQryH',#18,'Port_4077727_4','Flow',$,#4693411,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693417=IfcDistributionPort('2ED4Q7Pfs8C0RNdpTuK5Ry',#18,'Port_4077926_1','Flow',$,#4693416,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693422=IfcDistributionPort('1RGBf8eZTnN_yY_g7CS0yZ',#18,'Port_4077926_2','Flow',$,#4693421,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693427=IfcDistributionPort('3PYvZcRUO9IQokPdwenCo1',#18,'Port_4077926_3','Flow',$,#4693426,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693432=IfcDistributionPort('0rlO7W2UjbClpMxi6GRodK',#18,'Port_4077926_4','Flow',$,#4693431,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693437=IfcDistributionPort('1mdtITHbeIDjUqWbHiGZQr',#18,'Port_4098201_1','Flow',$,#4693436,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693442=IfcDistributionPort('0md7SLEHPvYLUYp8plZG0G',#18,'Port_4098201_2','Flow',$,#4693441,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693447=IfcDistributionPort('0gNgojHPkmqzEcvBNjoq5E',#18,'Port_4098201_3','Flow',$,#4693446,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693452=IfcDistributionPort('3hGdE_oT$ee5cHXe20L$YY',#18,'Port_4098201_4','Flow',$,#4693451,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693459=IfcDistributionPort('2nFhMMGOkT$4U2uydus4If',#18,'InPort_4306322_1','Flow',$,#4693458,$,.SINK.) no tiene representación.
# El producto #4693466=IfcDistributionPort('2_H2aw2m46og543bdo7US4',#18,'InPort_4306322_2','Flow',$,#4693465,$,.SINK.) no tiene representación.
# El producto #4693472=IfcDistributionPort('3DujHCWfo4va$P0Sg9FngB',#18,'InPort_4306322_3','Flow',$,#4693471,$,.SINK.) no tiene representación.
# El producto #4693478=IfcDistributionPort('3LY_m67Q3rIi$GPkCP2P_y',#18,'Port_4306322_4','Flow',$,#4693477,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693483=IfcDistributionPort('16XNEiW2YcchU_zzWMi1DB',#18,'Port_4306322_5','Flow',$,#4693482,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693488=IfcDistributionPort('0D$ABYZFEfzt8NwXOZlWXQ',#18,'Port_4306322_6','Flow',$,#4693487,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693493=IfcDistributionPort('2y71KgZiUchctQorIXm6gg',#18,'Port_4306322_7','Flow',$,#4693492,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693499=IfcDistributionPort('2mRhvxuTlfVdNNSgvVKsNJ',#18,'Port_4423585_1','Flow',$,#4693498,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693506=IfcDistributionPort('0BCbkMOTQbDT5bPkiS_xTV',#18,'Port_4423587_1','Flow',$,#4693505,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693512=IfcDistributionPort('29CZtEbh5TjaN1_CKV8bG$',#18,'Port_4525764_0','Flow',$,#4693511,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693519=IfcDistributionPort('0DerKDxfGsnI4rsqKm7HxF',#18,'Port_4525764_1','Flow',$,#4693518,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693526=IfcDistributionPort('29_ej529FO$mxr_l3wswq$',#18,'Port_4526192_1','Flow',$,#4693525,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693533=IfcDistributionPort('0fmLN7kRs8BrSiEWmljsVh',#18,'Port_4526192_2','Flow',$,#4693532,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693539=IfcDistributionPort('2R1YJP0GpkfnoKm$8y3oj4',#18,'Port_4526192_3','Flow',$,#4693538,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693546=IfcDistributionPort('3kkMxOoz59m$w12PfZ6vQY',#18,'Port_4526244_0','Flow',$,#4693545,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693553=IfcDistributionPort('2eMAteU2JeOYB4HWNjU$9r',#18,'Port_4526244_1','Flow',$,#4693552,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693560=IfcDistributionPort('3X58nUeUvP_dnZJEonzE9T',#18,'Port_4526600_0','Flow',$,#4693559,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693567=IfcDistributionPort('2zVfPR7GStaTEa3h_zy0Ol',#18,'Port_4526600_1','Flow',$,#4693566,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693572=IfcDistributionPort('0xkF3Lm$v5PMNsaeDumj1I',#18,'Port_4560432_1','Flow',$,#4693571,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693577=IfcDistributionPort('3CQkB32iX1si7IcoVc232x',#18,'Port_4560432_2','Flow',$,#4693576,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693582=IfcDistributionPort('3YLgCUTp21$90kLAfKjAvX',#18,'Port_4560432_3','Flow',$,#4693581,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693587=IfcDistributionPort('1xKbKTJ2B_ldh18vTytzO7',#18,'Port_4560432_4','Flow',$,#4693586,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693592=IfcDistributionPort('0707nTgNnjF15RgRD$g0dG',#18,'Port_4560432_5','Flow',$,#4693591,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693597=IfcDistributionPort('1cG1ji04lmZhz8fR9GNO69',#18,'Port_4560432_6','Flow',$,#4693596,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693602=IfcDistributionPort('2lRHKBIyzwJVh7UEpmv7_V',#18,'Port_4560432_7','Flow',$,#4693601,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693607=IfcDistributionPort('2jbgRav7DgEZjnmZVSrmcS',#18,'Port_4560432_8','Flow',$,#4693606,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693612=IfcDistributionPort('20nljnfu125BB_pQa16u1O',#18,'Port_4560432_9','Flow',$,#4693611,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693617=IfcDistributionPort('2lS$cExQ5uFQxG05AUDsRu',#18,'Port_4560432_10','Flow',$,#4693616,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693622=IfcDistributionPort('1KDmL0BKzmD0A$kI44C00b',#18,'Port_4560432_12','Flow',$,#4693621,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693627=IfcDistributionPort('1ySmCyl5TSvi941LvfAqVc',#18,'Port_4560432_13','Flow',$,#4693626,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693633=IfcDistributionPort('0eBm6asktv1ZgTyssGCm6h',#18,'Port_4585803_0','Flow',$,#4693632,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693640=IfcDistributionPort('28ukMCi3QfzE51gtSN1sEU',#18,'Port_4585803_1','Flow',$,#4693639,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693646=IfcDistributionPort('2UQtA2chw7xAs1cyhe1wCv',#18,'Port_4586257_0','Flow',$,#4693645,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693652=IfcDistributionPort('1Xpoofv8jD9qBSD6rnmx5o',#18,'Port_4586257_1','Flow',$,#4693651,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693659=IfcDistributionPort('1Dzhe5wgrWWifYJCEf1J2g',#18,'Port_4650957_1','Flow',$,#4693658,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693665=IfcDistributionPort('0WT3ilVqAQF9Hb3F5bT$q0',#18,'Port_4653061_1','Flow',$,#4693664,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693671=IfcDistributionPort('3lf0oe0yH2Ql9RzjdyOCLz',#18,'Port_4653061_2','Flow',$,#4693670,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693677=IfcDistributionPort('3lWV_Non$jm6ATZESEEZPh',#18,'Port_4653061_3','Flow',$,#4693676,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693683=IfcDistributionPort('1Mq$dZp1qJceoAWA0ucWwZ',#18,'Port_4653061_4','Flow',$,#4693682,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693689=IfcDistributionPort('07KS8SeFhYBVicNNicunT0',#18,'Port_4653061_5','Flow',$,#4693688,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693695=IfcDistributionPort('0IvokIWIZ3Y4ohYZEswNbp',#18,'Port_4653061_6','Flow',$,#4693694,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693701=IfcDistributionPort('1Ld1xSFOufw_EksD3vvY3A',#18,'Port_4653061_7','Flow',$,#4693700,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693707=IfcDistributionPort('15WRIqgeYiTLlmz2w_Helc',#18,'Port_4653061_8','Flow',$,#4693706,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693713=IfcDistributionPort('3UWlkB5DcJX9saAPixNyys',#18,'Port_4653061_9','Flow',$,#4693712,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693719=IfcDistributionPort('1Dc4wOsB5P9ojhc3Onurpn',#18,'Port_4653061_10','Flow',$,#4693718,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693725=IfcDistributionPort('18BLblOdwFPRAcuOkJOIki',#18,'Port_4653140_1','Flow',$,#4693724,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693731=IfcDistributionPort('1BTmGjxdZughx_slJm7yks',#18,'Port_4653140_2','Flow',$,#4693730,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693737=IfcDistributionPort('2eTxCo84C2FYDYcQ25sggs',#18,'Port_4653140_3','Flow',$,#4693736,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693743=IfcDistributionPort('3PuqY9tmvH2LJdYQj0dD1J',#18,'Port_4653140_4','Flow',$,#4693742,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693749=IfcDistributionPort('3I139N7gTi8OHiR$GczYoH',#18,'Port_4653140_5','Flow',$,#4693748,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693755=IfcDistributionPort('2FC4IEviZarJW5jog0ik4H',#18,'Port_4653140_6','Flow',$,#4693754,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693761=IfcDistributionPort('0bmNMg2UjyqoIfgkbxFpho',#18,'Port_4653140_7','Flow',$,#4693760,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693767=IfcDistributionPort('0HGVX61VySE7WLQqUTX6_c',#18,'Port_4653140_8','Flow',$,#4693766,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693773=IfcDistributionPort('2E3tDoQqQSCvp32MGO$qsu',#18,'Port_4653140_9','Flow',$,#4693772,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693779=IfcDistributionPort('06zJFDVc26SpMCThPiQtnT',#18,'Port_4653140_10','Flow',$,#4693778,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693785=IfcDistributionPort('15oPVcN7onXgFiHkQ$JBeC',#18,'Port_4653455_1','Flow',$,#4693784,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693791=IfcDistributionPort('1mat37JUIGmNZCgR2JRhC1',#18,'Port_4653455_2','Flow',$,#4693790,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693797=IfcDistributionPort('2_y_SbLtjZ5xEzLmQm8uuZ',#18,'Port_4653455_3','Flow',$,#4693796,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693803=IfcDistributionPort('3Jda3iHy1XOdcG296HE2Gm',#18,'Port_4653455_4','Flow',$,#4693802,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693809=IfcDistributionPort('3H1XDBXEbSYFWmVnN2DYs4',#18,'Port_4653455_5','Flow',$,#4693808,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693815=IfcDistributionPort('389f9p8yhqONpJtWiUKiTG',#18,'Port_4653455_6','Flow',$,#4693814,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693821=IfcDistributionPort('1Iw9amOE09A_Hj37Ky9VRU',#18,'Port_4653455_7','Flow',$,#4693820,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693827=IfcDistributionPort('27l3EDW_GzvHz35b5EKl9x',#18,'Port_4653455_8','Flow',$,#4693826,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693833=IfcDistributionPort('1ynLV_naRm5nqf00KF68ao',#18,'Port_4653455_9','Flow',$,#4693832,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693839=IfcDistributionPort('1f7S4j1eMklYVW2HkNqcZD',#18,'Port_4653455_10','Flow',$,#4693838,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693845=IfcDistributionPort('0svV7iWDIzR675LeuHuLv4',#18,'Port_4654830_0','Flow',$,#4693844,$,.SOURCEANDSINK.) no tiene representación.
# El producto #4693852=IfcDistributionPort('18jgYH6tYX5d_fS_Qf5fSD',#18,'Port_4654830_1','Flow',$,#4693851,$,.SOURCEANDSINK.) no tiene representación.
# El producto #126=IfcBuilding('1xakq9FM19ow5_dAvqT$xT',#18,'',$,$,#124,$,'',.ELEMENT.,$,$,#125) no tiene representación.
# El producto #130=IfcBuildingStorey('00d3mnb_fF49jPsgKYE6As',#18,'BASE_CIMENTACION',$,'Nivel:Nivel 1',#129,$,'BASE_CIMENTACION',.ELEMENT.,726.27) no tiene representación.
# El producto #134=IfcBuildingStorey('29TFpHBYXAnw12nix37b4C',#18,'BASE_ESTRUCT',$,'Nivel:Nivel 1',#133,$,'BASE_ESTRUCT',.ELEMENT.,726.42) no tiene representación.
# El producto #138=IfcBuildingStorey('2Oe7O06FfDr9UR3BjZFGie',#18,'BASE_EST Metalica',$,'Nivel:Nivel 1',#137,$,'BASE_EST Metalica',.ELEMENT.,727.169843816129) no tiene representación.
# El producto #142=IfcBuildingStorey('1c9hnn$Z94J9gzlxGkwVYb',#18,'BASE_PORTICO',$,'Nivel:Nivel 1',#141,$,'BASE_PORTICO',.ELEMENT.,730.99) no tiene representación.
# El producto #146=IfcBuildingStorey('1r_3F7BT5FBPAyyFMqubAq',#18,'BASE_U',$,'Nivel:Nivel 1',#145,$,'BASE_U',.ELEMENT.,731.79) no tiene representación.
# El producto #150=IfcBuildingStorey('29TFpHBYXAnw12nix37bGc',#18,'SUPERIOR_PÓRTICO',$,'Nivel:Nivel 1',#149,$,'SUPERIOR_PÓRTICO',.ELEMENT.,732.99) no tiene representación.
# El producto #154=IfcBuildingStorey('3ox7StaWj64QA8KNELRpzf',#18,'BASE_T',$,'Nivel:Nivel 1',#153,$,'BASE_T',.ELEMENT.,735.19) no tiene representación.
# El producto #158=IfcBuildingStorey('22206DsZT85OlCaEfuJx6s',#18,'BASE_POR_TRAFO',$,'Nivel:Nivel 1',#157,$,'BASE_POR_TRAFO',.ELEMENT.,739.18) no tiene representación.
# El producto #162=IfcBuildingStorey('22206DsZT85OlCaEfuJx7D',#18,'SUP_PORTI_TRAFO',$,'Nivel:Nivel 1',#161,$,'SUP_PORTI_TRAFO',.ELEMENT.,740.205) no tiene representación.
# El producto #166=IfcBuildingStorey('3ox7StaWj64QA8KNELRpv_',#18,'BASE_S',$,'Nivel:Nivel 1',#165,$,'BASE_S',.ELEMENT.,741.28) no tiene representación.
# El producto #170=IfcBuildingStorey('3ox7StaWj64QA8KNELRpqL',#18,'BASE_R',$,'Nivel:Nivel 1',#169,$,'BASE_R',.ELEMENT.,751.84) no tiene representación.
# [Open3D WARNING] [ViewControl] SetViewPoint() failed because window height and width are not set.

# %%
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(all_points)

# Visualizar la nube de puntos
o3d.visualization.draw_geometries([pcd])

# %%
o3d.io.write_point_cloud('nube_de_puntos.xyz', pcd)
# Out:
# True
